# %%
k = 34
l = 45
m = 54
k+l+m
# Out:
# 133

# %%
k - l
# Out:
# -11

# %%
l - m
# Out:
# -9

# %%
k*l*m
# Out:
# 82620

# %%
k/l
# Out:
# 0.7555555555555555

# %%
i = 3.4
j = 4.3
i+j
# Out:
# 7.699999999999999

# %%
i - j
# Out:
# -0.8999999999999999

# %%
i*k
# Out:
# 115.6

# %%
i*j
# Out:
# 14.62

# %%
j / i
# Out:
# 1.2647058823529411

# %%
k // j
# Out:
# 7.0

# %%
k / j
# Out:
# 7.906976744186047

# %%
22.7 / 11.4
# Out:
# 1.9912280701754386

# %%
22.7 // 11.4
# Out:
# 1.0

# %%
13 % 4 #remaining
# Out:
# 1

# %%
22.7 % 11.4
# Out:
# 11.299999999999999

# %%
4 % 2
# Out:
# 0

# %%
4 / 2
# Out:
# 2.0

# %%
4 ** 2
# Out:
# 16

# %%
999 ** 999
# Out:
# ...

# %%
4 ** 0.5
# Out:
# 2.0

# %%
8 ** (1/3)
# Out:
# 2.0

# %%
a = -4

# %%
-a
# Out:
# 4

# %% [markdown]
# #### Associativity

# %%
8 + ((4 * 3) / 2 )- 18
# Out:
# -4.0

# %%
((10 ** 2) // 3) / 3
# Out:
# 11.0
